# %%
# %matplotlib inline
import numpy as np
from astropy.modeling import models, fitting
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
plt.style.use('jpg')

# %%
hdulist = fits.open('../data/post_stamp_profiles/candy_1_hsc-i.fits')
data = hdulist[1].data
mask = hdulist[2].data

# %%
plt.hist(data.flatten(), log=True);
print data.mean(), data.std(), np.median(data)
# Out:
# 0.0578659 0.853011 0.00927408

# %%
f1, a1 = plt.subplots(1,2,figsize=(14,6))
f1.subplots_adjust(wspace=-0.1)
a1[0].imshow(data, cmap='gray_r', vmin=-0.1, vmax=0.25, origin='lower')
a1[1].imshow(mask, cmap='gray_r', vmax=1, origin='lower');
